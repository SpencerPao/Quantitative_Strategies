# %% [markdown]
# # Intrinsic Valuation of a Company using Discounted Cash Flows (To Firm)
#
# $$
# \begin{aligned}
# \sum_{t=1}^N \frac{Cash Flow To Firm_{t}}{(1+r)^{t}}
# \end{aligned}
# $$
# Cash Flow to Firm = Expected Cash flow to firm in period t \
# r = Weighted Cost of Capital (WACC) = Weight of Equity * Cost of Equity + Weight of Debt * Cost of Debt \
# N = Life of the asset
#
# # Key Assumptions when using Cash Flow to Firm
# Cash flows considered are cash flows from assets, prior to any debt payments but after firm has reinvested to create growth assets\
# Discount rate reflects the cost of raising both debt and equity financing, in proportion to their use
# ### NOTE: This is DIFFERENT from the DCF valuation of Cash flow to equity (Detailed in a future video)

# %%
# Loading in my key from my previous video... from the source Financial Modeling Prep...
import pandas as pd
import requests
import finance_scrapper as fs
import numpy as np

# %%
# Company Ticker
# Domino's pizza
tick = 'XOM'

# %%
# Getting industry multiples for later...
IM = fs.get_industry_multiples()
IM
# Out:
# <ipython-input-3-945db5fedc27>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IM = fs.get_industry_multiples()
# 1                                  Number  of firms  \
# Industry Name
# Category                                        NaN
# Advertising                                      47
# Aerospace/Defense                                77
# Air Transport                                    18
# Apparel                                          51
# ...                                             ...
# Trucking                                         33
# Utility (General)                                16
# Utility  (Water)                                 17
# Total Market                                   7053
# Total  Market (without financials)             5878
#
# 1                                                  EV/EBITDAR&D  \
# Industry Name
# Category                            Only  positive EBITDA firms
# Advertising                                                9.02
# Aerospace/Defense                                         12.06
# Air Transport                                              6.50
# Apparel                                                   10.84
# ...                                                         ...
# Trucking                                                   6.40
# Utility (General)                                         14.12
# Utility  (Water)                                          19.01
# Total Market                                              15.05
# Total  Market (without financials)                        11.72
#
# 1                                                     EV/EBITDA  \
# Industry Name
# Category                            Only  positive EBITDA firms
# Advertising                                                9.20
# Aerospace/Defense                                         14.94
# Air Transport                                              6.54
# Apparel                                                   10.93
# ...                                                         ...
# Trucking                                                   9.08
# Utility (General)                                         14.13
# Utility  (Water)                                          19.02
# Total Market                                              17.54
# Total  Market (without financials)                        13.75
#
# 1                                                       EV/EBIT  \
# Industry Name
# Category                            Only  positive EBITDA firms
# Advertising                                               15.12
# Aerospace/Defense                                         19.77
# Air Transport                                             12.00
# Apparel                                                   17.56
# ...                                                         ...
# Trucking                                                    NaN
# Utility (General)                                         24.65
# Utility  (Water)                                          29.10
# Total Market                                              28.99
# Total  Market (without financials)                        22.97
#
# 1                                                EV/EBIT  (1-t) EV/EBITDAR&D  \
# Industry Name
# Category                            Only  positive EBITDA firms   All  firms
# Advertising                                               19.34        12.51
# Aerospace/Defense                                         24.61        12.30
# Air Transport                                             15.61         8.65
# Apparel                                                   20.66        14.25
# ...                                                         ...          ...
# Trucking                                                    NaN        13.65
# Utility (General)                                         29.12        15.40
# Utility  (Water)                                          36.73        20.13
# Total Market                                              35.78        17.04
# Total  Market (without financials)                        28.31        13.26
#
# 1                                    EV/EBITDA     EV/EBIT EV/EBIT  (1-t)
# Industry Name
# Category                            All  firms  All  firms     All  firms
# Advertising                              12.85       15.86          20.28
# Aerospace/Defense                        15.30       19.82          24.68
# Air Transport                             8.71       12.00          15.61
# Apparel                                  14.42       17.65          20.77
# ...                                        ...         ...            ...
# Trucking                                 23.80         NaN            NaN
# Utility (General)                        15.41       24.65          29.12
# Utility  (Water)                         20.14       29.34          37.02
# Total Market                             20.19       29.86          36.86
# Total  Market (without financials)       15.82       23.80          29.33
#
# [97 rows x 9 columns]

# %%
key = pd.read_csv('key.txt', header = None)[0][0]

# %%
# Getting the full financial statement
full_financial_statement = fs.get_full_financial_statement_as_reported(ticker = tick, key = key, period = 'quarter')

# %%
# Income Statement
IS = fs.get_income_statement(ticker = tick, limit = 4, key = key, period = 'quarter')
IS
# Out:
# fillingDate                                                              2020-11-04  \
# date                                                                     2020-09-30
# symbol                                                                          XOM
# fillingDate                                                              2020-11-04
# acceptedDate                                                    2020-11-04 13:00:19
# period                                                                           Q3
# revenue                                                                 46199000000
# costOfRevenue                                                                     0
# grossProfit                                                             46199000000
# grossProfitRatio                                                                  1
# researchAndDevelopmentExpenses                                                    0
# generalAndAdministrativeExpenses                                         2444000000
# sellingAndMarketingExpenses                                                       0
# otherExpenses                                                                     0
# operatingExpenses                                                        2444000000
# costAndExpenses                                                          2444000000
# interestExpense                                                          -279000000
# depreciationAndAmortization                                              4983000000
# ebitda                                                                   4611000000
# ebitdaratio                                                               0.0998074
# operatingIncome                                                          -372000000
# operatingIncomeRatio                                                    -0.00805212
# totalOtherIncomeExpensesNet                                               257000000
# incomeBeforeTax                                                          -372000000
# incomeBeforeTaxRatio                                                    -0.00805212
# incomeTaxExpense                                                                  0
# netIncome                                                                -372000000
# netIncomeRatio                                                          -0.00805212
# eps                                                                           -0.15
# epsdiluted                                                                    -0.15
# weightedAverageShsOut                                                    4271000000
# weightedAverageShsOutDil                                                 4271000000
# link                              https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                         https://www.sec.gov/Archives/edgar/data/34088/...
#
# fillingDate                                                              2020-08-05  \
# date                                                                     2020-06-30
# symbol                                                                          XOM
# fillingDate                                                              2020-08-05
# acceptedDate                                                    2020-08-05 14:03:10
# period                                                                           Q2
# revenue                                                                 32277000000
# costOfRevenue                                                            2.0964e+10
# grossProfit                                                             11313000000
# grossProfitRatio                                                           0.350497
# researchAndDevelopmentExpenses                                             2.14e+08
# generalAndAdministrativeExpenses                                         7563000000
# sellingAndMarketingExpenses                                                       0
# otherExpenses                                                              2.71e+08
# operatingExpenses                                                       12964000000
# costAndExpenses                                                         33928000000
# interestExpense                                                           317000000
# depreciationAndAmortization                                              4916000000
# ebitda                                                                   3682000000
# ebitdaratio                                                                0.114075
# operatingIncome                                                         -1651000000
# operatingIncomeRatio                                                      -0.051151
# totalOtherIncomeExpensesNet                                               225000000
# incomeBeforeTax                                                         -1640000000
# incomeBeforeTaxRatio                                                       -0.05081
# incomeTaxExpense                                                          -4.71e+08
# netIncome                                                               -1080000000
# netIncomeRatio                                                             -0.03346
# eps                                                                        -0.25287
# epsdiluted                                                                 -0.25287
# weightedAverageShsOut                                                    4271000000
# weightedAverageShsOutDil                                                 4271000000
# link                              https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                         https://www.sec.gov/Archives/edgar/data/34088/...
#
# fillingDate                                                     2020-05-06 00:00:00  \
# date                                                                     2020-03-31
# symbol                                                                          XOM
# fillingDate                                                     2020-05-06 00:00:00
# acceptedDate                                                    2020-05-06 14:06:03
# period                                                                           Q1
# revenue                                                                 55134000000
# costOfRevenue                                                             4.038e+10
# grossProfit                                                             14754000000
# grossProfitRatio                                                           0.267603
# researchAndDevelopmentExpenses                                             2.88e+08
# generalAndAdministrativeExpenses                                         9411000000
# sellingAndMarketingExpenses                                                       0
# otherExpenses                                                              2.69e+08
# operatingExpenses                                                       15787000000
# costAndExpenses                                                         56167000000
# interestExpense                                                           249000000
# depreciationAndAmortization                                              5819000000
# ebitda                                                                   5970000000
# ebitdaratio                                                                0.108282
# operatingIncome                                                         -1033000000
# operatingIncomeRatio                                                      -0.018736
# totalOtherIncomeExpensesNet                                               249000000
# incomeBeforeTax                                                          -258000000
# incomeBeforeTaxRatio                                                       -0.00468
# incomeTaxExpense                                                           5.12e+08
# netIncome                                                                -610000000
# netIncomeRatio                                                            -0.011064
# eps                                                                        -0.14286
# epsdiluted                                                                 -0.14286
# weightedAverageShsOut                                                    4270000000
# weightedAverageShsOutDil                                                 4270000000
# link                              https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                         https://www.sec.gov/Archives/edgar/data/34088/...
#
# fillingDate                                                     2020-02-26 00:00:00  \
# date                                                                     2019-12-31
# symbol                                                                          XOM
# fillingDate                                                     2020-02-26 00:00:00
# acceptedDate                                                    2020-02-26 16:15:19
# period                                                                           Q4
# revenue                                                                 63024000000
# costOfRevenue                                                            4.4254e+10
# grossProfit                                                             18770000000
# grossProfitRatio                                                           0.297823
# researchAndDevelopmentExpenses                                             3.57e+08
# generalAndAdministrativeExpenses                                        10817000000
# sellingAndMarketingExpenses                                                       0
# otherExpenses                                                              2.07e+08
# operatingExpenses                                                       16304000000
# costAndExpenses                                                         60558000000
# interestExpense                                                           201000000
# depreciationAndAmortization                                              4923000000
# ebitda                                                                  12238000000
# ebitdaratio                                                                 0.19418
# operatingIncome                                                          2466000000
# operatingIncomeRatio                                                       0.039128
# totalOtherIncomeExpensesNet                                              2972000000
# incomeBeforeTax                                                          6414000000
# incomeBeforeTaxRatio                                                       0.101771
# incomeTaxExpense                                                          1.424e+09
# netIncome                                                                5690000000
# netIncomeRatio                                                             0.090283
# eps                                                                         1.33255
# epsdiluted                                                                  1.33255
# weightedAverageShsOut                                                    4270000000
# weightedAverageShsOutDil                                                 4270000000
# link                              https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                         https://www.sec.gov/Archives/edgar/data/34088/...
#
# fillingDate                                                     2019-11-06 00:00:00
# date                                                                     2019-09-30
# symbol                                                                          XOM
# fillingDate                                                     2019-11-06 00:00:00
# acceptedDate                                                    2019-11-06 13:34:22
# period                                                                           Q3
# revenue                                                                 63422000000
# costOfRevenue                                                            4.4138e+10
# grossProfit                                                             19284000000
# grossProfitRatio                                                           0.304059
# researchAndDevelopmentExpenses                                             2.99e+08
# generalAndAdministrativeExpenses                                        10429000000
# sellingAndMarketingExpenses                                                       0
# otherExpenses                                                              3.57e+08
# operatingExpenses                                                       15958000000
# costAndExpenses                                                         60096000000
# interestExpense                                                           232000000
# depreciationAndAmortization                                              4873000000
# ebitda                                                                   9749000000
# ebitdaratio                                                                0.153716
# operatingIncome                                                          3326000000
# operatingIncomeRatio                                                       0.052442
# totalOtherIncomeExpensesNet                                               431000000
# incomeBeforeTax                                                          4721000000
# incomeBeforeTaxRatio                                                       0.074438
# incomeTaxExpense                                                          1.474e+09
# netIncome                                                                3170000000
# netIncomeRatio                                                             0.049983
# eps                                                                         0.74221
# epsdiluted                                                                  0.74221
# weightedAverageShsOut                                                    4271000000
# weightedAverageShsOutDil                                                 4271000000
# link                              https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                         https://www.sec.gov/Archives/edgar/data/34088/...

# %%
# Balance Sheet
BS = fs.get_balance_sheet(ticker = tick, limit = 4, key = key, period = 'quarter')
BS
# Out:
# fillingDate                                                                     2020-11-04  \
# date                                                                            2020-09-30
# symbol                                                                                 XOM
# fillingDate                                                                     2020-11-04
# acceptedDate                                                           2020-11-04 13:00:19
# period                                                                                  Q3
# cashAndCashEquivalents                                                          8832000000
# shortTermInvestments                                                            4.3609e+10
# cashAndShortTermInvestments                                                    52441000000
# netReceivables                                                                 19974000000
# inventory                                                                                0
# otherCurrentAssets                                                                       0
# totalCurrentAssets                                                             48693000000
# propertyPlantEquipmentNet                                                     250496000000
# goodwill                                                                                 0
# intangibleAssets                                                                1.5245e+10
# goodwillAndIntangibleAssets                                                    15245000000
# longTermInvestments                                                                      0
# taxAssets                                                                                0
# otherNonCurrentAssets                                                                    0
# totalNonCurrentAssets                                                         265741000000
# otherAssets                                                                    43609000000
# totalAssets                                                                   358043000000
# accountPayables                                                                  3.334e+10
# shortTermDebt                                                                   2.1911e+10
# taxPayables                                                                     1217000000
# deferredRevenue                                                                24467000000
# otherCurrentLiabilities                                                                  0
# totalCurrentLiabilities                                                        56468000000
# longTermDebt                                                                   46888000000
# deferredRevenueNonCurrent                                                                0
# deferredTaxLiabilitiesNonCurrent                                                         0
# otherNonCurrentLiabilities                                                               0
# totalNonCurrentLiabilities                                                     46888000000
# otherLiabilities                                                                         0
# totalLiabilities                                                              173431000000
# commonStock                                                                              0
# retainedEarnings                                                              407728000000
# accumulatedOtherComprehensiveIncomeLoss                                       -20189000000
# othertotalStockholdersEquity                                                             0
# totalStockholdersEquity                                                       184612000000
# totalLiabilitiesAndStockholdersEquity                                         358043000000
# totalInvestments                                                               43609000000
# totalDebt                                                                      46888000000
# netDebt                                                                        38056000000
# link                                     https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                                https://www.sec.gov/Archives/edgar/data/34088/...
#
# fillingDate                                                                     2020-08-05  \
# date                                                                            2020-06-30
# symbol                                                                                 XOM
# fillingDate                                                                     2020-08-05
# acceptedDate                                                           2020-08-05 14:03:10
# period                                                                                  Q2
# cashAndCashEquivalents                                                         12576000000
# shortTermInvestments                                                            4.3192e+10
# cashAndShortTermInvestments                                                    12576000000
# netReceivables                                                                 19036000000
# inventory                                                                       1.9657e+10
# otherCurrentAssets                                                               1.747e+09
# totalCurrentAssets                                                             53016000000
# propertyPlantEquipmentNet                                                     250524000000
# goodwill                                                                                 0
# intangibleAssets                                                                1.4763e+10
# goodwillAndIntangibleAssets                                                    14763000000
# longTermInvestments                                                             4.3192e+10
# taxAssets                                                                       2.4725e+10
# otherNonCurrentAssets                                                           1.4763e+10
# totalNonCurrentAssets                                                         308479000000
# otherAssets                                                                    16510000000
# totalAssets                                                                   361495000000
# accountPayables                                                                 3.3216e+10
# shortTermDebt                                                                   2.2952e+10
# taxPayables                                                                     1102000000
# deferredRevenue                                                                24725000000
# otherCurrentLiabilities                                                          1.102e+09
# totalCurrentLiabilities                                                        57270000000
# longTermDebt                                                                   46563000000
# deferredRevenueNonCurrent                                                                0
# deferredTaxLiabilitiesNonCurrent                                                2.4725e+10
# otherNonCurrentLiabilities                                                      4.5784e+10
# totalNonCurrentLiabilities                                                    124042000000
# otherLiabilities                                                                4.5784e+10
# totalLiabilities                                                              181312000000
# commonStock                                                                     1.5812e+10
# retainedEarnings                                                              412124000000
# accumulatedOtherComprehensiveIncomeLoss                                       -43234000000
# othertotalStockholdersEquity                                                   -2.1617e+10
# totalStockholdersEquity                                                       180183000000
# totalLiabilitiesAndStockholdersEquity                                         361495000000
# totalInvestments                                                               43192000000
# totalDebt                                                                      69515000000
# netDebt                                                                        56939000000
# link                                     https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                                https://www.sec.gov/Archives/edgar/data/34088/...
#
# fillingDate                                                            2020-05-06 00:00:00  \
# date                                                                            2020-03-31
# symbol                                                                                 XOM
# fillingDate                                                            2020-05-06 00:00:00
# acceptedDate                                                           2020-05-06 14:06:03
# period                                                                                  Q1
# cashAndCashEquivalents                                                         11412000000
# shortTermInvestments                                                                     0
# cashAndShortTermInvestments                                                    11412000000
# netReceivables                                                                 20871000000
# inventory                                                                       1.6501e+10
# otherCurrentAssets                                                               1.465e+09
# totalCurrentAssets                                                             50249000000
# propertyPlantEquipmentNet                                                     248409000000
# goodwill                                                                                 0
# intangibleAssets                                                                         0
# goodwillAndIntangibleAssets                                                    14165000000
# longTermInvestments                                                             4.2981e+10
# taxAssets                                                                       2.4863e+10
# otherNonCurrentAssets                                                           1.4165e+10
# totalNonCurrentAssets                                                         305555000000
# otherAssets                                                                    15630000000
# totalAssets                                                                   355804000000
# accountPayables                                                                          0
# shortTermDebt                                                                            0
# taxPayables                                                                     1203000000
# deferredRevenue                                                                24863000000
# otherCurrentLiabilities                                                          1.203e+09
# totalCurrentLiabilities                                                        64773000000
# longTermDebt                                                                   31857000000
# deferredRevenueNonCurrent                                                                0
# deferredTaxLiabilitiesNonCurrent                                                2.4863e+10
# otherNonCurrentLiabilities                                                      4.5568e+10
# totalNonCurrentLiabilities                                                    108952000000
# otherLiabilities                                                                4.5568e+10
# totalLiabilities                                                              173725000000
# commonStock                                                                     1.5636e+10
# retainedEarnings                                                              416919000000
# accumulatedOtherComprehensiveIncomeLoss                                       -48678000000
# othertotalStockholdersEquity                                                   -2.4339e+10
# totalStockholdersEquity                                                       182079000000
# totalLiabilitiesAndStockholdersEquity                                         355804000000
# totalInvestments                                                               42981000000
# totalDebt                                                                      59612000000
# netDebt                                                                        48200000000
# link                                     https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                                https://www.sec.gov/Archives/edgar/data/34088/...
#
# fillingDate                                                            2020-02-26 00:00:00  \
# date                                                                            2019-12-31
# symbol                                                                                 XOM
# fillingDate                                                            2020-02-26 00:00:00
# acceptedDate                                                           2020-02-26 16:15:19
# period                                                                                  Q4
# cashAndCashEquivalents                                                          3089000000
# shortTermInvestments                                                                     0
# cashAndShortTermInvestments                                                     3089000000
# netReceivables                                                                 26966000000
# inventory                                                                       1.8528e+10
# otherCurrentAssets                                                               1.469e+09
# totalCurrentAssets                                                             50052000000
# propertyPlantEquipmentNet                                                     259651000000
# goodwill                                                                                 0
# intangibleAssets                                                                         0
# goodwillAndIntangibleAssets                                                    16363000000
# longTermInvestments                                                             4.3164e+10
# taxAssets                                                                        2.562e+10
# otherNonCurrentAssets                                                             9.73e+09
# totalNonCurrentAssets                                                         312545000000
# otherAssets                                                                    11199000000
# totalAssets                                                                   362597000000
# accountPayables                                                                          0
# shortTermDebt                                                                            0
# taxPayables                                                                     1580000000
# deferredRevenue                                                                25620000000
# otherCurrentLiabilities                                                           1.58e+09
# totalCurrentLiabilities                                                        63989000000
# longTermDebt                                                                   26481000000
# deferredRevenueNonCurrent                                                                0
# deferredTaxLiabilitiesNonCurrent                                                 2.562e+10
# otherNonCurrentLiabilities                                                      4.7569e+10
# totalNonCurrentLiabilities                                                    106958000000
# otherLiabilities                                                                4.7569e+10
# totalLiabilities                                                              170947000000
# commonStock                                                                     1.5637e+10
# retainedEarnings                                                              421341000000
# accumulatedOtherComprehensiveIncomeLoss                                       -38986000000
# othertotalStockholdersEquity                                                   -1.9493e+10
# totalStockholdersEquity                                                       191650000000
# totalLiabilitiesAndStockholdersEquity                                         362597000000
# totalInvestments                                                               43164000000
# totalDebt                                                                      47074000000
# netDebt                                                                        43985000000
# link                                     https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                                https://www.sec.gov/Archives/edgar/data/34088/...
#
# fillingDate                                                            2019-11-06 00:00:00
# date                                                                            2019-09-30
# symbol                                                                                 XOM
# fillingDate                                                            2019-11-06 00:00:00
# acceptedDate                                                           2019-11-06 13:34:22
# period                                                                                  Q3
# cashAndCashEquivalents                                                          5351000000
# shortTermInvestments                                                                     0
# cashAndShortTermInvestments                                                     5351000000
# netReceivables                                                                 25308000000
# inventory                                                                        1.759e+10
# otherCurrentAssets                                                               1.759e+09
# totalCurrentAssets                                                             50008000000
# propertyPlantEquipmentNet                                                     257065000000
# goodwill                                                                                 0
# intangibleAssets                                                                         0
# goodwillAndIntangibleAssets                                                    15921000000
# longTermInvestments                                                              4.292e+10
# taxAssets                                                                       2.6513e+10
# otherNonCurrentAssets                                                            9.368e+09
# totalNonCurrentAssets                                                         309353000000
# otherAssets                                                                    11127000000
# totalAssets                                                                   359361000000
# accountPayables                                                                          0
# shortTermDebt                                                                            0
# taxPayables                                                                     2458000000
# deferredRevenue                                                                26513000000
# otherCurrentLiabilities                                                          2.458e+09
# totalCurrentLiabilities                                                        64195000000
# longTermDebt                                                                   26089000000
# deferredRevenueNonCurrent                                                                0
# deferredTaxLiabilitiesNonCurrent                                                2.6513e+10
# otherNonCurrentLiabilities                                                      4.5455e+10
# totalNonCurrentLiabilities                                                    105251000000
# otherLiabilities                                                                4.5455e+10
# totalLiabilities                                                              169446000000
# commonStock                                                                     1.5795e+10
# retainedEarnings                                                              419367000000
# accumulatedOtherComprehensiveIncomeLoss                                       -38554000000
# othertotalStockholdersEquity                                                   -1.9277e+10
# totalStockholdersEquity                                                       189915000000
# totalLiabilitiesAndStockholdersEquity                                         359361000000
# totalInvestments                                                               42920000000
# totalDebt                                                                      47308000000
# netDebt                                                                        41957000000
# link                                     https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                                https://www.sec.gov/Archives/edgar/data/34088/...

# %%
# Cash Flow
CF = fs.get_cash_flow_statement(ticker = tick, limit = 4, key = key, period = 'quarter')
CF
# Out:
# fillingDate                                                                      2020-11-04  \
# date                                                                             2020-09-30
# symbol                                                                                  XOM
# fillingDate                                                                      2020-11-04
# acceptedDate                                                            2020-11-04 13:00:19
# period                                                                                   Q3
# netIncome                                                                        -709000000
# depreciationAndAmortization                                                      4983000000
# deferredIncomeTax                                                                         0
# stockBasedCompensation                                                                    0
# changeInWorkingCapital                                                          -3521000000
# accountsReceivables                                                                       0
# inventory                                                                         -1.15e+08
# accountsPayables                                                                          0
# otherWorkingCapital                                                             -7775000000
# otherNonCashItems                                                                         0
# netCashProvidedByOperatingActivities                                              617000000
# investmentsInPropertyPlantAndEquipment                                          -3291000000
# acquisitionsNet                                                                           0
# purchasesOfInvestments                                                                    0
# salesMaturitiesOfInvestments                                                              0
# otherInvestingActivites                                                                   0
# netCashUsedForInvestingActivites                                                 1401000000
# debtRepayment                                                                      5.73e+08
# commonStockIssued                                                                         0
# commonStockRepurchased                                                                    0
# dividendsPaid                                                                   -3716000000
# otherFinancingActivites                                                                   0
# netCashUsedProvidedByFinancingActivities                                        -4494000000
# effectOfForexChangesOnCash                                                                0
# netChangeInCash                                                                 -3744000000
# cashAtEndOfPeriod                                                                8832000000
# cashAtBeginningOfPeriod                                                         12576000000
# operatingCashFlow                                                                 617000000
# capitalExpenditure                                                               3291000000
# freeCashFlow                                                                    -2674000000
# link                                      https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                                 https://www.sec.gov/Archives/edgar/data/34088/...
#
# fillingDate                                                                      2020-08-05  \
# date                                                                             2020-06-30
# symbol                                                                                  XOM
# fillingDate                                                                      2020-08-05
# acceptedDate                                                            2020-08-05 14:03:10
# period                                                                                   Q2
# netIncome                                                                       -1169000000
# depreciationAndAmortization                                                      4916000000
# deferredIncomeTax                                                                         0
# stockBasedCompensation                                                                    0
# changeInWorkingCapital                                                          10270000000
# accountsReceivables                                                                       0
# inventory                                                                        -2.069e+09
# accountsPayables                                                                          0
# otherWorkingCapital                                                             -4254000000
# otherNonCashItems                                                                         0
# netCashProvidedByOperatingActivities                                              157000000
# investmentsInPropertyPlantAndEquipment                                          -4417000000
# acquisitionsNet                                                                           0
# purchasesOfInvestments                                                            -7.96e+08
# salesMaturitiesOfInvestments                                                              0
# otherInvestingActivites                                                            1.32e+08
# netCashUsedForInvestingActivites                                                -5081000000
# debtRepayment                                                                        -1e+06
# commonStockIssued                                                                         0
# commonStockRepurchased                                                                    0
# dividendsPaid                                                                   -3715000000
# otherFinancingActivites                                                           9.993e+09
# netCashUsedProvidedByFinancingActivities                                         6277000000
# effectOfForexChangesOnCash                                                         -3.2e+07
# netChangeInCash                                                                  1164000000
# cashAtEndOfPeriod                                                               12576000000
# cashAtBeginningOfPeriod                                                         11412000000
# operatingCashFlow                                                                 157000000
# capitalExpenditure                                                              -4417000000
# freeCashFlow                                                                    -4260000000
# link                                      https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                                 https://www.sec.gov/Archives/edgar/data/34088/...
#
# fillingDate                                                                      2020-05-06  \
# date                                                                             2020-03-31
# symbol                                                                                  XOM
# fillingDate                                                                      2020-05-06
# acceptedDate                                                            2020-05-06 14:06:03
# period                                                                                   Q1
# netIncome                                                                        -770000000
# depreciationAndAmortization                                                      5819000000
# deferredIncomeTax                                                                         0
# stockBasedCompensation                                                                    0
# changeInWorkingCapital                                                           -587000000
# accountsReceivables                                                                       0
# inventory                                                                         2.245e+09
# accountsPayables                                                                          0
# otherWorkingCapital                                                            -14524000000
# otherNonCashItems                                                                         0
# netCashProvidedByOperatingActivities                                             6274000000
# investmentsInPropertyPlantAndEquipment                                          -5945000000
# acquisitionsNet                                                                           0
# purchasesOfInvestments                                                           -1.033e+09
# salesMaturitiesOfInvestments                                                              0
# otherInvestingActivites                                                            6.11e+08
# netCashUsedForInvestingActivites                                                -6367000000
# debtRepayment                                                                        -2e+06
# commonStockIssued                                                                         0
# commonStockRepurchased                                                            -3.05e+08
# dividendsPaid                                                                   -3719000000
# otherFinancingActivites                                                          1.2811e+10
# netCashUsedProvidedByFinancingActivities                                         8785000000
# effectOfForexChangesOnCash                                                        -3.69e+08
# netChangeInCash                                                                  8323000000
# cashAtEndOfPeriod                                                               11412000000
# cashAtBeginningOfPeriod                                                          3089000000
# operatingCashFlow                                                                6274000000
# capitalExpenditure                                                              -5945000000
# freeCashFlow                                                                      329000000
# link                                      https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                                 https://www.sec.gov/Archives/edgar/data/34088/...
#
# fillingDate                                                             2020-02-26 00:00:00  \
# date                                                                             2019-12-31
# symbol                                                                                  XOM
# fillingDate                                                             2020-02-26 00:00:00
# acceptedDate                                                            2020-02-26 16:15:19
# period                                                                                   Q4
# netIncome                                                                        5730000000
# depreciationAndAmortization                                                      4923000000
# deferredIncomeTax                                                                 -9.44e+08
# stockBasedCompensation                                                             7.41e+08
# changeInWorkingCapital                                                            250000000
# accountsReceivables                                                               -2.64e+09
# inventory                                                                           7.2e+07
# accountsPayables                                                                  3.725e+09
# otherWorkingCapital                                                            -13937000000
# otherNonCashItems                                                                -5.575e+09
# netCashProvidedByOperatingActivities                                             6352000000
# investmentsInPropertyPlantAndEquipment                                          -6704000000
# acquisitionsNet                                                                           0
# purchasesOfInvestments                                                           -1.546e+09
# salesMaturitiesOfInvestments                                                              0
# otherInvestingActivites                                                           3.986e+09
# netCashUsedForInvestingActivites                                                -4264000000
# debtRepayment                                                                     9.974e+09
# commonStockIssued                                                                         0
# commonStockRepurchased                                                            -1.73e+08
# dividendsPaid                                                                   -3716000000
# otherFinancingActivites                                                         -1.0541e+10
# netCashUsedProvidedByFinancingActivities                                        -4456000000
# effectOfForexChangesOnCash                                                         1.06e+08
# netChangeInCash                                                                 -2262000000
# cashAtEndOfPeriod                                                                3089000000
# cashAtBeginningOfPeriod                                                          5351000000
# operatingCashFlow                                                                6352000000
# capitalExpenditure                                                              -6704000000
# freeCashFlow                                                                     -352000000
# link                                      https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                                 https://www.sec.gov/Archives/edgar/data/34088/...
#
# fillingDate                                                             2019-11-06 00:00:00
# date                                                                             2019-09-30
# symbol                                                                                  XOM
# fillingDate                                                             2019-11-06 00:00:00
# acceptedDate                                                            2019-11-06 13:34:22
# period                                                                                   Q3
# netIncome                                                                        3247000000
# depreciationAndAmortization                                                      4873000000
# deferredIncomeTax                                                                         0
# stockBasedCompensation                                                                    0
# changeInWorkingCapital                                                           4357000000
# accountsReceivables                                                                       0
# inventory                                                                                 0
# accountsPayables                                                                          0
# otherWorkingCapital                                                            -14187000000
# otherNonCashItems                                                                         0
# netCashProvidedByOperatingActivities                                             9079000000
# investmentsInPropertyPlantAndEquipment                                          -6285000000
# acquisitionsNet                                                                           0
# purchasesOfInvestments                                                            -8.02e+08
# salesMaturitiesOfInvestments                                                              0
# otherInvestingActivites                                                            9.37e+08
# netCashUsedForInvestingActivites                                                -6150000000
# debtRepayment                                                                     4.956e+09
# commonStockIssued                                                                         0
# commonStockRepurchased                                                                    0
# dividendsPaid                                                                   -3716000000
# otherFinancingActivites                                                          -2.906e+09
# netCashUsedProvidedByFinancingActivities                                        -1666000000
# effectOfForexChangesOnCash                                                        -1.25e+08
# netChangeInCash                                                                  1138000000
# cashAtEndOfPeriod                                                                5351000000
# cashAtBeginningOfPeriod                                                          4213000000
# operatingCashFlow                                                                9079000000
# capitalExpenditure                                                              -6285000000
# freeCashFlow                                                                     2794000000
# link                                      https://www.sec.gov/Archives/edgar/data/34088/...
# finalLink                                 https://www.sec.gov/Archives/edgar/data/34088/...

# %% [markdown]
# # Calculating the Free Cash Flow to Firm
# $$
# FCFF = EBIT*(1-Marginal Tax Rate) - (Capital Expenditures - Depreciation) - Change in Noncash Working Capital
# $$

# %%
FCFF = (sum(IS.loc['netIncome'][0:4]) + sum(IS.loc['interestExpense'][0:4]) + sum(IS.loc['incomeTaxExpense'][0:4]))*(1-0.21) - (sum(CF.loc['capitalExpenditure'][0:4]) - full_financial_statement.loc['depreciationdepletionandamortization'][0:4].sum()) -  sum(CF.loc['changeInWorkingCapital'][0:4])

# %%
FCFF/1000000000 # (293 million)
# Out:
# 63.04199

# %% [markdown]
# # Let's Calculate the Cost of Equity
# ### My 5 year Beta: 1.57 whereas Yahoo Finance and Financial Modeling Prep has ~1.7
# # <center>Results of my Regression</center>
# ![image info](Beta_DPZ_11172020.PNG)

# %% [markdown]
# # Equation for Cost of Equity
# $$
# \begin{aligned}
# CostOfEquity = Riskless Rate + Beta * Equity Risk Premium
# \end{aligned}
# $$
#
# <center>Cost of Equity = 10 Year Treasury Rate + Beta * Implied Equity Risk Premium </center>
# <center>Cost of Equity = 0.0089 + 0.4606 * 0.00535 </center>
#
# Note: I obtained the implied equity risk premium from Damodaran at http://pages.stern.nyu.edu/~adamodar/ \
# Cost of Equity is the CAPM model

# %%
COE = 0.0089 + 1.1972*0.0535
print(COE)
# Out:
# 0.0729502

# %% [markdown]
# # Equation for Cost of Debt
# ### After Tax Cost of Debt = (Risk free rate + Default Spread of Debt) * (1- Tax Rate)
# ##### S\&P rated DPZ of a rating B+ which has a typical default spread of 3.51%
# http://pages.stern.nyu.edu/~adamodar/New_Home_Page/datafile/ratings.htm \
# ##### Adding this default spread to 10 year risk free rate (US): 0.89% + 3.51%  = 4.4%
# ##### Calculating the After Tax cost of Debt: 4.4 % * (1- 21%) = 3.476%

# %%
rating_risk = 0.0089 + 0.0078
COD = rating_risk * (1-0.21)
COD
# Out:
# 0.013193

# %% [markdown]
# # Calculating Weighted Average Cost of Capital
# ##### Now that we have the Cost of Equity and Debt, we need to figure out the weights.
# $$
# \begin{aligned}
# \frac{Equity}{Equity + Debt}
# \end{aligned}
# $$
# Where Equity is the Market Capital.
# $$
# \begin{aligned}
# \frac{Debt}{Equity + Debt}
# \end{aligned}
# $$

# %%
# Weights for Equity:
equity_weight = fs.get_market_capital(tick,key) / (fs.get_market_capital(tick,key) + BS.loc['totalDebt'][0])
debt_weight = BS.loc['totalDebt'][0] / (fs.get_market_capital(tick,key) + BS.loc['totalDebt'][0])

# %%
print(equity_weight, debt_weight)
# Out:
# 0.7526770854064236 0.24732291459357636

# %%
# We now have all the components for a Weighted Average Cost of Capital..
WACC = equity_weight*COE + debt_weight*COD
print(WACC) # Or 1.626 %
# Out:
# 0.05817087512804874

# %% [markdown]
# # Expected Growth Rate:
# ### <center> Expected Growth Rate = Reinvestment * Return on Capital </center>
# where
# $$Reinvestment = \frac{Capital Expenditures - Depreciation + Change in Noncash Working Capital}{EBIT(1-tax)}$$
# and
# $$Return On Capital (ROC) = \frac{EBIT_{n+1}*(1-tax rate)}{BookValueOfEquity_n + BookValueOfDebt_n - Cash_n}$$

# %%
reinvestment_rate = ((-1)*sum(CF.loc['capitalExpenditure'][0:4]) - sum(IS.loc['depreciationAndAmortization'][0:4]) + sum(CF.loc['changeInWorkingCapital'][0:4])) / (sum(IS.loc['netIncome'][0:4]) + sum(IS.loc['interestExpense'][0:4]) + sum(IS.loc['incomeTaxExpense'][0:4]))*(1-0.21)
reinvestment_rate
# Out:
# -0.06426446873320193

# %%
ROC = (sum(IS.loc['netIncome'][0:4]) + sum(IS.loc['interestExpense'][0:4]) + sum(IS.loc['incomeTaxExpense'][0:4]))*(1-0.21) / ((-1)*BS.loc['totalStockholdersEquity'][1]+BS.loc['totalDebt'][1] - BS.loc['cashAndCashEquivalents'][1])
ROC
# Out:
# -0.035774479893544514

# %%
expected_growth = reinvestment_rate * ROC
print(expected_growth)
# Out:
# 0.0022990279445652528

# %%
# Reinvestment in Stable Growth
expected_growth / ROC
# Out:
# -0.06426446873320193

# %% [markdown]
# # Calculating the Expected Free Cash Flow to Firm

# %%
#Beta goes toward 1
# Market premium is assumed to be the same..
# Update the WACC
# Assuming that the debt ratio is the same.. (~20:100) or use a debt ratio of the industry average..
# remultiple the weights with the cost of debt and equity to get new WACC
# Cost of Debt * weight of debt + Cost of Equity * weight of debt
# where Cost of equity is now : Risk Free Rate + 1 * Market Premium
# where Cost of debt is the same (if low)
# Remultiply the weights to get new WACC
new_COE =  0.0089 + 1 * 0.00535
new_COD = .016669
new_WACC = 0.2 * new_COD + 0.8 * new_COE
new_WACC #
# Out:
# 0.0147338

# %%
# Reinvestment rate for < 5 years
# Growth / ROC
r_rate = expected_growth / ROC
r_rate
# Out:
# -0.06426446873320193

# %%
# After Tax Operating Income
ATOI = (sum(IS.loc['netIncome'][0:4]) + sum(IS.loc['interestExpense'][0:4]) + sum(IS.loc['incomeTaxExpense'][0:4]))*(1-0.21)

# %%
# Years to discount from
years = 6
ATOI_growth = []
reinvestment_income = []
FCFF = []

# Starting at current year
ATOI_growth.append(ATOI)
reinvestment_income.append(None)
FCFF.append(None)

for y in range(1,years):
    Expected_After_Tax_Operating_Income = ATOI*(1+expected_growth)**y
    Expected_Reinvestment = r_rate*Expected_After_Tax_Operating_Income
    Expected_FCFF = Expected_After_Tax_Operating_Income - Expected_Reinvestment
    
    ATOI_growth.append(Expected_After_Tax_Operating_Income)
    reinvestment_income.append(Expected_Reinvestment)
    FCFF.append(Expected_FCFF)

# %%
Expected_FCFF = pd.DataFrame([ATOI_growth, reinvestment_income, FCFF])
Expected_FCFF.index = ['After Tax Operating Income', 'Reinvestment','FCFF']
column_names = []
for i in Expected_FCFF.columns:
    if i == 0:
        column_names.append('Current Year')
    else:
        column_names.append('Expected Year ' + str(i))
Expected_FCFF.columns = column_names
Expected_FCFF
# Out:
#                             Current Year  Expected Year 1  Expected Year 2  \
# After Tax Operating Income  4.408990e+09     4.419126e+09     4.429286e+09
# Reinvestment                         NaN    -2.839928e+08    -2.846457e+08
# FCFF                                 NaN     4.703119e+09     4.713932e+09
#
#                             Expected Year 3  Expected Year 4  Expected Year 5
# After Tax Operating Income     4.439469e+09     4.449676e+09     4.459906e+09
# Reinvestment                  -2.853001e+08    -2.859560e+08    -2.866135e+08
# FCFF                           4.724769e+09     4.735632e+09     4.746519e+09

# %% [markdown]
# # Calculating Terminal Value from Assumptions of Stable Growth
# # Terminal Value: Using the principals of the Gordon dividend growth model..
#  $$Terminal Value_n =\frac{Cash Flow_n}{(Discount Rate - Steady Growth)}$$ \
# Note: Since our DCF model will go 5 years in the future we will base our future 5 years from now \
# Book Value of Assets = Total Assets - Total Liabilities\
# I will use the WACC as the discount rate here...

# %%
# If your stable growth is greater than your new WACC, use a multiple
# Calculating the Terminal Value via the traditional DCF or via multiples..
def calculate_terminal_value(number_years):
    '''number_years: the number of years that you will discount back to the present from terminal value calculation'''
    if 0.03 < new_WACC:
        print('Stable Growth is ', 0.03, 'and the new Weighted Average Cost of Capital is ', new_WACC)
        print('Gordons model assumption is incorrect.. thus use a multiple')
        # Assuming that the market will grow at 3% a year indefinitley...
        # Reinvestment Growth Rate
        # Adjust your Return on Capital (Recalculate WACC from previously)
        stable_reinvestment_rate = 0.03 / new_WACC
        # Incorporating Terminal value numbers here

        # Expected After Tax Operating Income in Year 6 (Using stable growth)
        TV_ATOI = Expected_FCFF.iloc[0,-1] * (1 + 0.03)
        
        # Reinvestment Rate in Year 6
        TV_Reinvestment = TV_ATOI * stable_reinvestment_rate
        
        # New Free Cash Flow to Firm in Year 6
        FCFF_Final = TV_ATOI - TV_Reinvestment
        
        # Terminal Value at end of year 5
        # HOWEVER, if DISCOUNT RATE IS < GROWTH RATE, then the calculation of Terminal Value is USELESS! Use a multiple instead (EV/EBIT)
        TV = FCFF_Final / (new_WACC - 0.03) # where 0.03 is your expected growth
        
        # Discount this to present (in this case 5 years)
        Terminal_Value = (TV / (1 + WACC)**(len(Expected_FCFF.columns) - 1))
        print('Used Gordons way of calculating Terminal Value')
        return(Terminal_Value)
    else:
        # Getting the multiples from: http://pages.stern.nyu.edu/~adamodar/New_Home_Page/datafile/vebitda.html
        # DPZ is in the restaurant business.
        # Ratio used for positive EBITDA
        print('Used Relative Terminal Value')
        Terminal_Value = (float(IM.loc['Restaurant/Dining']['EV/EBIT'][0]) * Expected_FCFF.iloc[2,-1]) /(1+WACC)**number_years
        return(Terminal_Value)

# %%
Terminal_Value = calculate_terminal_value(5)
# Out:
# Used Relative Terminal Value

# %%
Terminal_Value / 1000000000 #in billions
# Out:
# 113.91194365735426

# %%
# Get Present Value of Free Cash Flows
PV_FCFF = 0
for i in range(1,Expected_FCFF.shape[1]):
    PV_FCFF += Expected_FCFF.loc['FCFF'][i] / (1 + new_WACC)**(i)
print('PV_FCFF:', PV_FCFF, 'or',PV_FCFF/1000000000,'billion')
# Out:
# PV_FCFF: 22613107702.660297 or 22.613107702660297 billion

# %%
# Intrinsic Value Calculation : Present Value of Cash Flow to Firm + Terminal Value (at same time line)
Value_Operating_Assets = PV_FCFF + Terminal_Value
Value_Operating_Assets
# Out:
# 136525051360.01456

# %%
# Add back in Cash and Cross Holdings of other companies...
# Dominos does not seem to have any holdings (So I will put this value at 0.)
Value_Of_Firm = Value_Operating_Assets + BS.loc['cashAndCashEquivalents'][0]
print('Value of Firm', Value_Of_Firm, 'or', Value_Of_Firm/1000000000, 'billion')
# Out:
# Value of Firm 145357051360.01456 or 145.35705136001457 billion

# %%
Value_Of_Equity = Value_Of_Firm - BS.loc['totalDebt'][0]
print('Value of Equity', Value_Of_Equity, 'or', Value_Of_Equity/1000000000, 'billion')
# Out:
# Value of Equity 98469051360.01456 or 98.46905136001456 billion

# %%
num_shares = fs.get_quote(tick, key).loc['sharesOutstanding'][0]
Value_Of_Firm / num_shares
# Out:
# 34.37775512545455
